# %% [markdown]
# This notebook aims to parse some raw html tables containing common food additive info into a useable JSON object that maps from the chemical name to something more understandable (eg. colour, sweetener).

# %%
import re
import pprint
import json

# %%
# clean up data
to_rm = ["<strong>", "</strong>", "<em>", "</em>", "&nbsp;"]
def clean(s: str) -> str:
    for x in to_rm:
        s = s.replace(x, "")
    s = s.replace("<br>", " ")
    s.strip()
    return s.lower()

def remove_number(s: str) -> str:
    s = s.split(" ")
    try:
        int(s[0][:-1])
        return " ".join(s[1:])
    except:
        return " ".join(s)
    
# we just want something short and simple; take the first part of the description
def take_first_item(s: str) -> str:
    s = s.split(", ")
    return s[0]

# given the column (index) representing keys and the column (index) representing the mapping,
# output an object
def parse(filename: str, from_col: str, to_col: str) -> object:
    with open(filename, "r") as file:
        x = file.read()
        
        # extract rows
        rows = re.findall("<tr>(.*?)<\/tr>", x)

        d = {}
        from_ind = None
        to_ind = None

        # extract cols
        for i, row in enumerate(rows):
            data = re.findall("<td>(.*?)<\/td>", row)
            if i == 0:
                for i in range(len(data)):
                    data[i] = data[i].replace("<strong>", "")
                    data[i] = data[i].replace("</strong>", "")
                    data[i] = data[i].replace("<br>", " ")
                from_ind = data.index(from_col)
                to_ind = data.index(to_col)
                continue
            if data[-1] == "&nbsp;":
                continue
            # print(data)
            chemical_name = clean(remove_number(data[from_ind]))
            chemical_simplified = clean(take_first_item(data[to_ind]))
            d[chemical_name] = chemical_simplified

        pprint.pprint(d)
        return d

# %%
# d = parse("raw_html_1.txt", "Functional Classes", "Technological Purpose")
# d = d | parse("raw_html_2.txt", "Functional Classes", "Technological Purpose")

# %%
d = parse("raw_html_3.txt", "Name of Food Additive", "Purpose")
# Out:
# {'acesulfame potassium': 'sweetener',
#  'acetic acid, glacial': 'preservative',
#  'acetic and fatty acid esters of glycerol': 'stabilizer',
#  'acetone peroxide': 'flour treatment agent',
#  'acetylated distarch adipate': 'thickener',
#  'acetylated distarch phosphate': 'thickener',
#  'acetylated oxidized starch': 'thickener',
#  'acid-treated starch': 'thickener',
#  'adipic acid': 'acidity regulator',
#  'advantame': 'flavour enhancer',
#  'agar': 'thickener',
#  'alanine, dl-': 'flavour enhancer',
#  'alginic acid': 'thickener',
#  'alitame': 'sweetener',
#  'alkaline treated starch': 'thickener',
#  'alkanet': 'colour',
#  'allura red ac': 'colour',
#  'alpha-amylase from aspergillus oryzae var.': 'flour treatment agent',
#  'alpha-amylase from bacillus megaterium expressed in bacillus subtilis': 'flour '
#                                                                           'treatment '
#                                                                           'agent',
#  'alpha-amylase from bacillus stearothermophilus': 'flour treatment agent',
#  'alpha-amylase from bacillus stearothermophilus expressed in bacillus subtilis': 'flour '
#                                                                                   'treatment '
#                                                                                   'agent',
#  'alpha-amylase from bacillus subtilis': 'flour treatment agent',
#  'aluminium ammonium sulfate': 'stabilizer',
#  'aluminium potassium sulfate': 'stabilizer',
#  'aluminium powder': 'surface colourant',
#  'aluminium silicate': 'anticaking agent',
#  'aluminium sodium sulfate': 'firming agent',
#  'aluminium sulfate': 'firming agent',
#  'amaranth': 'colour',
#  'ammonium acetate': 'acidity regulator',
#  'ammonium adipates': 'acidity regulator',
#  'ammonium alginate': 'thickener',
#  'ammonium carbonate': 'raising agent',
#  'ammonium chloride': 'flour treatment agent',
#  'ammonium dihydrogen phosphate': 'stabilizer',
#  'ammonium fumarate': 'acidity regulator',
#  'ammonium hydrogen carbonate': 'raising agent',
#  'ammonium hydroxide': 'acidity regulator',
#  'ammonium lactate': 'flour treatment agent',
#  'ammonium malate': 'acidity regulator',
#  'ammonium persulfate': 'flour treatment agent',
#  'ammonium phosphates': '',
#  'ammonium polyphosphate': 'texturizing agent',
#  'ammonium salts of phosphatidic acid': 'emulsifier',
#  'ammonium sulfate': 'stabilizer',
#  'annatto extracts, bixin-based': 'colour',
#  'annatto extracts, norbixin-based': 'colour',
#  'anoxomer': 'antioxidant',
#  'arabinogalactan': 'thickener',
#  'ascorbic acid, l-': 'sequestrant',
#  'ascorbyl palmitate': 'antioxidant',
#  'ascorbyl stearate': 'antioxidant',
#  'aspartame': 'sweetener',
#  'aspartame-acesulfame salt': 'sweetener',
#  'azodicarbonamide': 'flour treatment agent',
#  'azorubine (carmoisine)': 'colour',
#  'bakers yeast glycan': 'thickener',
#  'beeswax': 'thickener',
#  'beet red': 'colour',
#  'bentonite': 'anticaking agent',
#  'benzoic acid': 'preservative',
#  'benzoin gum': 'glazing agent',
#  'benzoyl peroxide': 'preservative',
#  'black carrot extract': 'colour',
#  'blackcurrant extract': 'colour',
#  'bleached starch': 'thickener',
#  'bone phosphate': 'thickener',
#  'brilliant black (black pn)': 'colour',
#  'brilliant blue fcf': 'colour',
#  'bromelain': 'stabilizer',
#  'brominated vegetable oils': 'stabilizer',
#  'brown fk': 'colour',
#  'brown ht': 'colour',
#  'butane': 'propellant',
#  'butylated hydroxyanisole': 'antioxidant',
#  'butylated hydroxytoluene': 'antioxidant',
#  'calcium 5â€™-guanylate': 'flavour enhancer',
#  'calcium 5â€™-inosinate': 'flavour enhancer',
#  'calcium 5â€™-ribonucleotides': 'flavour enhancer',
#  'calcium acetate': 'acidity regulator',
#  'calcium alginate': 'thickener',
#  'calcium aluminium silicate': 'anticaking agent',
#  'calcium ascorbate': 'antioxidant',
#  'calcium benzoate': 'preservative',
#  'calcium carbonate': 'stabilizer',
#  'calcium chloride': 'thickener synergist',
#  'calcium citrates': '',
#  'calcium cyclamate': 'sweetener',
#  'calcium di-l-glutamate': 'flavour enhancer',
#  'calcium dihydrogen diphosphate': 'stabilizer',
#  'calcium dihydrogen phosphate': 'texturizing agent',
#  'calcium disodium ethylenediaminetetraacetate': 'sequestrant',
#  'calcium ferrocyanide': 'anticaking agent',
#  'calcium formate': 'preservative',
#  'calcium fumarates': 'acidity regulator',
#  'calcium gluconate': 'sequestrant',
#  'calcium glycerophosphate': 'thickener',
#  'calcium hydrogen carbonate': 'stabilizer',
#  'calcium hydrogen malate': 'acidity regulator',
#  'calcium hydrogen phosphate': 'texturizing agent',
#  'calcium hydrogen sulfite': 'preservative',
#  'calcium hydroxide': 'firming agent',
#  'calcium iodate': 'flour treatment agent',
#  'calcium isoascorbate': 'antioxidant',
#  'calcium lactate': 'thickener',
#  'calcium lactobionate': 'stabilizer',
#  'calcium lignosulfonate, 40-65': 'encapsulating agent',
#  'calcium malate, d,l-': 'acidity regulator',
#  'calcium oleyl lactylate': 'stabilize',
#  'calcium oxide': 'flour treatment agent',
#  'calcium peroxide': 'flour treatment agent',
#  'calcium phosphates': '',
#  'calcium polyphosphate': 'texturizing agent',
#  'calcium propionate': 'preservative',
#  'calcium saccharin': 'sweetener',
#  'calcium silicate': 'anticaking agent',
#  'calcium sorbate': 'preservative',
#  'calcium stearoyl fumarate': 'emulsifier',
#  'calcium stearoyl lactylate': 'stabilizer',
#  'calcium sulfate': 'stabilizer',
#  'calcium sulfite': 'preservative',
#  'calcium tartrate, dl-': 'acidity regulator',
#  'candelilla wax': 'texturizing agent',
#  'canthaxanthin': 'colour',
#  'caramel i â€“ plain caramel': 'colour',
#  'caramel ii â€“ sulfite caramel': 'colour',
#  'caramel iii â€“ ammonia caramel': 'colour',
#  'caramel iv â€“ sulfite ammonia caramel': 'colour',
#  'carbohydrase from bacillus licheniformis': 'flour treatment agent',
#  'carbon black (hydrocarbon)': 'colour',
#  'carbon dioxide': 'propellant',
#  'carmines': 'colour',
#  'carnauba wax': 'glazing agent',
#  'carob bean gum': 'thickener',
#  'carotenal, beta-apo-8â€™-': 'colour',
#  'carotenes, beta-, blakeslea trispora': 'colour',
#  'carotenes, beta-, synthetic': 'colour',
#  'carotenes, beta-, vegetable': 'colour',
#  'carotenoic acid, ethyl ester, beta-apo-8â€²-': 'colour',
#  'carrageenan': 'thickener',
#  'carthamus yellow': 'colour',
#  'cassia gum': 'thickener',
#  'castor oil': 'plasticizer',
#  'chlorine': 'flour bleaching agent',
#  'chlorine dioxide': 'flour treatment agent',
#  'chloropentafluorethane': 'propellant',
#  'chlorophyllins, copper complexes, potassium and sodium salts': 'colour',
#  'chlorophylls': 'colour',
#  'chlorophylls, copper complexes': 'colour',
#  'cholic acid': 'emulsifier',
#  'choline acetate': 'emulsifier',
#  'choline carbonate': 'emulsifier',
#  'choline chloride': 'emulsifier',
#  'choline citrate': 'emulsifier',
#  'choline lactate': 'emulsifier',
#  'choline tartrate': 'emulsifier',
#  'citric acid': 'sequestrant',
#  'citric and fatty acid esters of glycerol': 'stabilizer',
#  'citrus red no. 2': 'colour',
#  'cross-linked sodium carboxymethyl cellulose (cross-linked cellulose gum)': 'binder',
#  'cupric sulfate': 'preservative',
#  'curcumin': 'colour',
#  'curdlan': 'thickener',
#  'cyclamic acid': 'sweetener',
#  'cyclodextrin, alpha': 'binder',
#  'cyclodextrin, beta': 'binder',
#  'cyclodextrin, gamma': 'binder',
#  'cyclotetraglucose syrup': 'carrier',
#  'cysteine, l- and its hydrochlorides â€“ sodium and potassium salts': 'flour '
#                                                                        'treatment '
#                                                                        'agent',
#  'cystine, l-and its hydrochlorides sodium and potassium salts': 'flour '
#                                                                  'treatment '
#                                                                  'agent',
#  'dehydroacetic acid': 'preservative',
#  'dextrins, roasted starch': 'thickener',
#  'diacetyltartaric and fatty acid esters of glycerol': 'stabilizer',
#  'diammonium hydrogen phosphate': 'thickener',
#  'dicalcium citrate': 'stabilizer',
#  'dicalcium diphosphate': 'texturizing agent',
#  'dichlorodifluormethane': 'propellant',
#  'dilauryl thiodipropionate': 'antioxidant',
#  'dimagnesium diphosphate': 'texturizing agent',
#  'dimethyl dicarbonate': 'preservative',
#  'dioctyl sodium sulfosuccinate': 'wetting agent',
#  'diphenyl': 'preservative',
#  'dipotassium 5â€™-guanylate': 'flavour enhancer',
#  'dipotassium diphosphate': 'stabilizer',
#  'dipotassium hydrogen phosphate': 'texturizing agent',
#  'dipotassium tartrate': 'sequestrant',
#  'disodium 5â€™-guanylate': 'flavour enhancer',
#  'disodium 5â€™-inosinate': 'flavour enhancer',
#  'disodium 5â€™-ribonucleotides': 'flavour enhancer',
#  'disodium diphosphate': 'texturizing agent',
#  'disodium ethylenediaminetetraacetate': 'stabilizer',
#  'disodium hydrogen phosphate': 'texturizing agent',
#  'disodium monohydrogen citrate': 'stabilizer',
#  'disodium succinate': 'flavour enhancer',
#  'distarch phosphate': 'thickener',
#  'distearyl thiodipropionate': 'antioxidant',
#  'dodecyl gallate': 'antioxidant',
#  'elderberry colour': 'colour',
#  'erythorbic acid (isoascorbic acid)': 'antioxidant',
#  'erythritol': 'sweetener',
#  'erythrosine': 'colour',
#  'ethoxylated mono- and di-glycerides': 'emulsifier',
#  'ethoxyquin': 'antioxidant',
#  'ethyl cellulose': 'thickener',
#  'ethyl gallate': 'antioxidant',
#  'ethyl hydroxyethyl cellulose': 'thickener',
#  'ethyl maltol': 'flavour enhancer',
#  'ethyl para-hydroxybenzoate': 'preservative',
#  'fast green fcf': 'colour',
#  'fatty acids': 'foam stabilizer',
#  'ferric (iii)-orthophosphate': 'carrier',
#  'ferric (iii)-pyrophosphate': 'carrier',
#  'ferric ammonium citrate': 'anticaking agent',
#  'ferrous carbonate': 'acidity regulator',
#  'ferrous gluconate': 'colour stabilizer',
#  'ferrous hexacyanomanganate': 'anticaking agent',
#  'ferrous lactate': 'colour retention agent',
#  'ficin': 'stabilizer',
#  'flavoxanthin': 'colour',
#  'formaldehyde': 'preservative',
#  'formic acid': 'preservative',
#  'fumaric acid': 'acidity regulator',
#  'gardenia blue': 'colour',
#  'gardenia yellow': 'colour',
#  'gelatin': 'thickener',
#  'gellan gum': 'thickener',
#  'gluconic acid, d': 'raising agent',
#  'glucono delta-lactone': 'sequestrant',
#  'glucose oxidase': 'antioxidant',
#  'glutamic acid, l(+)-': 'flavour enhancer',
#  'glycerol': 'bodying agent',
#  'glycerol diacetate': 'carrier',
#  'glycerol ester of gum rosin': 'emulsifier',
#  'glycerol ester of tall oil rosin': 'emulsifier',
#  'glycerol ester of wood rosin': 'stabilizer',
#  'glycerol, methyl, or pentaerithrytol esters of colophane': 'glazing agent',
#  'glycine': 'flavour enhancer',
#  'glycyrrhizin': 'sweetener',
#  'gold, metallic': 'colour',
#  'grape skin extract': 'colour',
#  'green s': 'colour',
#  'guaiac resin': 'antioxidant',
#  'guanylic acid, 5â€™-': 'flavour enhancer',
#  'guar gum': 'thickener',
#  'gum arabic (acacia gum)': 'thickener',
#  'gum ghatti': 'thickener',
#  'gum guaicum': 'preservative',
#  'heptonolactone, 1,4-': 'sequestrant',
#  'heptyl para-hydroxybenzoate': 'preservative',
#  'hexamethylene tetramine': 'preservative',
#  'hexylresorcinol, 4-': 'colour retention agent',
#  'hibiscus colour': 'colour',
#  'hydrochloric acid': 'acidity regulator',
#  'hydrogen': 'packaging gas',
#  'hydrogenated poly-1-decenes': 'glazing agent',
#  'hydroxypropyl cellulose': 'thickener',
#  'hydroxypropyl distarch phosphate': 'thickener',
#  'hydroxypropyl methyl cellulose': 'thickener',
#  'hydroxypropyl starch': 'thickener',
#  'indigotine (indigo carmine)': 'colour',
#  'inosinic acid, 5â€™-': 'flavour enhancer',
#  'invertases': 'stabilizer',
#  'iron oxide, black': 'colour',
#  'iron oxide, red': 'colour',
#  'iron oxide, yellow': 'colour',
#  'iron tartrate': 'anticaking agent',
#  'isobutane': 'propellant',
#  'isomalt (hydrogenated isomaltulose)': 'texturizing agent',
#  'isopropyl citrates': 'sequestrant',
#  'karaya gum': 'thickener',
#  'konjac flour': 'thickener',
#  'kryptoxanthin': 'colour',
#  'lactic acid, l-, d- and dl-': 'acidity regulator',
#  'lactic and fatty acid esters of glycerol': 'stabilizer',
#  'lactitol': 'texturizing agent',
#  'lactylated fatty acid esters of glycerol and propylene glycol': 'emulsifier',
#  'lanolin': 'glazing agent',
#  'lauric arginate ethyl ester': 'preservative',
#  'lecithin': 'emulsifier',
#  'lecithin citrate': 'preservative',
#  'lecithin, hydroxylated': 'emulsifier',
#  'lecithin, partially hydrolysed': 'emulsifier',
#  'leucine, l-': 'flavour enhancer',
#  'lipases': 'flavour enhancer',
#  'lithol rubine bk': 'colour',
#  'lutein esters from tagetes erecta': 'colour',
#  'lutein from tagetes erecta': 'colour',
#  'lycopene, blakeslea trispora': 'colour',
#  'lycopene, synthetic': 'colour',
#  'lycopene, tomato': 'colour',
#  'lysin hydrochloride': 'flavour enhancer',
#  'lysozyme': 'preservative',
#  'magnesium carbonate': 'colour retention agent',
#  'magnesium chloride': 'stabilizer',
#  'magnesium citrate': 'acidity regulator',
#  'magnesium di-l-glutamate': 'flavour enhancer',
#  'magnesium dihydrogen diphosphate': 'stabilizer',
#  'magnesium dihydrogen phosphate': 'thickener',
#  'magnesium gluconate': 'flavour enhancer',
#  'magnesium hydrogen phosphate': 'thickener',
#  'magnesium hydroxide': 'colour retention agent',
#  'magnesium hydroxide carbonate': 'colour retention agent',
#  'magnesium lactate, dl': 'flour treatment agent',
#  'magnesium oxide': 'anticaking agent',
#  'magnesium phosphates': '',
#  'magnesium silicate, synthetic': 'dusting agent',
#  'magnesium stearate': 'binder',
#  'magnesium sulfate': 'flavour enhancer',
#  'magnesium trisilicate': 'dusting agent',
#  'malic acid, dl-': 'sequestrant',
#  'maltitol': 'texturizing agent',
#  'maltitol syrup': 'texturizing agent',
#  'maltol': 'flavour enhancer',
#  'manascorubin': 'colour',
#  'mannitol': 'texturizing agent',
#  'metatartaric acid': 'thickener',
#  'methacrylate copolymer, anionic': 'glazing agent',
#  'methacrylate copolymer, basic': 'encapsulating agent',
#  'methacrylate copolymer, neutral': 'glazing agent',
#  'methyl cellulose': 'thickener',
#  'methyl esters of fatty acids': 'glazing agent',
#  'methyl ethyl cellulose': 'thickener',
#  'methyl glucoside-coconut oil ester': 'emulsifier',
#  'methyl para-hydroxybenzoate': 'preservative',
#  'methylphenylpolysiloxane': 'antifoaming agent',
#  'microcrystalline cellulose (cellulose gel)': 'thickener',
#  'microcrystalline wax': 'glazing agent',
#  'mineral oil, food grade': 'sealing agent',
#  'mineral oil, high viscosity': 'sealing agent',
#  'mineral oil, medium and low viscosity, class ii': 'sealing agent',
#  'mineral oil, medium and low viscosity, class iii': 'sealing agent',
#  'mineral oil, medium viscosity': 'sealing agent',
#  'modified starches': '',
#  'mono- and di- glycerides of fatty acids': 'stabilizer',
#  'monoammonium l-glutamate': 'flavour enhancer',
#  'monocalcium citrate': 'stabilizer',
#  'monopotassium l-glutamate': 'flavour enhancer',
#  'monopotassium tartrate': 'sequestrant',
#  'monosodium l-glutamate': 'flavour enhancer',
#  'monosodium succinate': 'flavour enhancer',
#  'monosodium tartrate': 'sequestrant',
#  'monostarch phosphate': 'thickener',
#  'natamycin (pimaricin)': 'preservative',
#  'neohesperidine dihydrochalcone': 'sweetener',
#  'neotame': 'flavour enhancer',
#  'nicotinic acid': 'colour retention agent',
#  'nisin': 'preservative',
#  'nitrogen': 'propellant',
#  'nitrogen oxides': 'flour treatment agent',
#  'nitrosyl chloride': 'flour treatment agent',
#  'nitrous oxide': 'propellant',
#  'oat gum': 'thickener',
#  'octafluorcyclobutane': 'propellant',
#  'octenyl succinic acid (osa) modified gum arabic': 'emulsifier',
#  'octyl gallate': 'antioxidant',
#  'orchil': 'colour',
#  'ortho-phenylphenol': 'preservative',
#  'oxidized starch': 'thickener',
#  'oxystearin': 'sequestrant',
#  'papain': 'flavour enhancer',
#  'paprika extract': 'colour',
#  'paprika oleoresin': 'colour',
#  'paraffin wax': 'glazing agent',
#  'patent blue v': 'colour',
#  'pectins': 'thickener',
#  'pentapotassium triphosphate': 'texturizing agent',
#  'pentasodium triphosphate': 'texturizing agent',
#  'peptones': 'emulsifier',
#  'petroleum jelly (petrolatum)': 'sealing agent',
#  'petroleum wax': 'sealing agent',
#  'phosphated distarch phosphate': 'thickener',
#  'phosphoric acid': 'sequestrant',
#  'phytic acid': 'preservative',
#  'polydextroses': 'thickener',
#  'polydimethylsiloxane': 'emulsifier',
#  'polyethylene glycol': 'binder',
#  'polyglycerol esters of fatty acids': 'stabilizer',
#  'polyglycerol esters of interesterified ricinoleic acid': 'emulsifier',
#  'polyglycitol syrup': 'sweetener',
#  'polyoxyethylene (20) sorbitan monolaurate': 'emulsion stabilizer',
#  'polyoxyethylene (20) sorbitan monooleate': 'emulsion stabilizer',
#  'polyoxyethylene (20) sorbitan monopalmitate': 'emulsifier',
#  'polyoxyethylene (20) sorbitan monostearate': 'emulsion stabilizer',
#  'polyoxyethylene (20) sorbitan tristearate': 'emulsion stabilizer',
#  'polyoxyethylene (40) stearate': 'emulsifier',
#  'polyoxyethylene (8) stearate': 'emulsifier',
#  'polyvinyl alcohol': 'binder',
#  'polyvinyl alcohol (pva)-polyethylene glycol (peg) graft co-polymer': 'binder',
#  'polyvinylpyrrolidone': 'bodying agent',
#  'polyvinylpyrrolidone, insoluble': 'stabilizer',
#  'polyvinylpyrrolidone-vinyl acetate copolymer': 'glazing agent',
#  'ponceau 4r (cochineal red a)': 'colour',
#  'ponceau sx': 'colour',
#  'potassium 5â€™-inosinate': 'flavour enhancer',
#  'potassium acetate': 'preservative',
#  'potassium acetates': '',
#  'potassium adipates': 'acidity regulator',
#  'potassium alginate': 'thickener',
#  'potassium aluminium silicate': 'carrier',
#  'potassium aluminium silicate-based pearlescent pigments (pas-bpp)': '',
#  'potassium aluminium silicate-based pearlescent pigments (pas-bpp) potassium aluminium silicate-based pearlescent pigments coated with titanium dioxide, type i': 'colour',
#  'potassium aluminium silicate-based pearlescent pigments coated with iron oxide, type ii': 'colour',
#  'potassium aluminium silicate-based pearlescent pigments coated with titanium dioxide and iron oxide, type iii': 'colour',
#  'potassium ascorbate': 'antioxidant',
#  'potassium benzoate': 'preservative',
#  'potassium bisulfite': 'preservative',
#  'potassium carbonate': 'stabilizer',
#  'potassium chloride': 'thickener synergist',
#  'potassium citrates': '',
#  'potassium diacetate': 'preservative',
#  'potassium dihydrogen citrate': 'stabilizer',
#  'potassium dihydrogen phosphate': 'texturizing agent',
#  'potassium ferrocyanide': 'anticaking agent',
#  'potassium fumarates': 'acidity regulator',
#  'potassium gluconate': 'sequestrant',
#  'potassium hydrogen carbonate': 'stabilizer',
#  'potassium hydrogen malate': 'acidity regulator',
#  'potassium hydrogen sulfate': 'acidity regulator',
#  'potassium hydroxide': 'acidity regulator',
#  'potassium iodate': 'flour treatment agent',
#  'potassium isoascorbate': 'antioxidant',
#  'potassium lactate': 'humectants',
#  'potassium malate': 'acidity regulator',
#  'potassium metabisulfite': 'preservative',
#  'potassium nitrate': 'preservative',
#  'potassium nitrite': 'preservative',
#  'potassium persulfate': 'flour treatment agent',
#  'potassium phosphates': 'acidity regulator',
#  'potassium polyaspartate': 'stabilizer',
#  'potassium polyphosphate': 'texturizing agent',
#  'potassium propionate': 'preservative',
#  'potassium saccharin': 'sweetener',
#  'potassium silicate': 'anticaking agent',
#  'potassium sodium l(+)-tartrate': 'sequestrant',
#  'potassium sorbate': 'preservative',
#  'potassium sulfate': 'acidity regulator',
#  'potassium sulfite': 'preservative',
#  'potassium tartrates': '',
#  'powdered cellulose': 'thickener',
#  'processed euchema seaweed (pes)': 'thickener',
#  'propane': 'propellant',
#  'propionic acid': 'preservative',
#  'propyl gallate': 'antioxidant',
#  'propyl para-hydroxybenzoate': 'preservative',
#  'propylene glycol': 'wetting agent',
#  'propylene glycol alginate': 'thickener',
#  'propylene glycol esters of fatty acids': 'emulsifier',
#  'protease from streptomyces fradiae': 'stabilizer',
#  'proteasefrom aspergillus oryzae. var.': 'stabilizer',
#  'proteases from bacillus subtilis': 'stabilizer',
#  'pullulan': 'thickener',
#  'purple corn colour': 'colour',
#  'purple sweet potato colour': 'colour',
#  'quillaia extract type 1': 'emulsifier',
#  'quillaia extract type 2': 'emulsifier',
#  'quillaia extract type 3': 'foaming agent',
#  'quinoline yellow': 'colour',
#  'rebaudioside a from multiple gene donors expressed in yarrowia lipolytica': 'sweetener',
#  'red cabbage colour': 'colour',
#  'red radish colour': 'colour',
#  'rhodoxanthin': 'colour',
#  'riboflavin 5â€²-phosphate sodium': 'colour',
#  'riboflavin from bacillus subtilis': 'colour',
#  'riboflavin, synthetic': 'colour',
#  'rice bran wax': 'glazing agent',
#  'rosemary extract': 'antioxidant',
#  'rubixanthin': 'colour',
#  'saccharin': 'sweetener',
#  'salts of myristic, palmitic and stearic acids with ammonia, calcium, potassium and sodium': 'stabilizer',
#  'salts of oleic acid with calcium, potassium and sodium': 'stabilizer',
#  'sandalwood': 'colour',
#  'shellac, bleached': 'surface-finishing agent',
#  'silicon dioxide, amorphous': 'defoaming agent',
#  'silver': 'colour',
#  'sodium acetate': 'sequestrant',
#  'sodium acetates': '',
#  'sodium adipates': 'acidity regulator',
#  'sodium alginate': 'thickener',
#  'sodium aluminium phosphate, acidic': 'texturizing agent',
#  'sodium aluminium phosphate, basic': 'texturizing agent',
#  'sodium aluminium silicate': 'anticaking agent',
#  'sodium ascorbate': 'antioxidant',
#  'sodium benzoate': 'preservative',
#  'sodium calcium polyphosphate': 'stabilizer',
#  'sodium carbonate': 'thickener',
#  'sodium carboxymethyl cellulose (cellulose gum)': 'thickener',
#  'sodium carboxymethyl cellulose, enzymatically hydrolysed (cellulose gum, enzymatically hydrolyzed)': 'thickener',
#  'sodium cyclamate': 'sweetener',
#  'sodium dehydroacetate': 'preservative',
#  'sodium diacetate': 'sequestrant',
#  'sodium dihydrogen citrate': 'stabilizer',
#  'sodium dihydrogen phosphate': 'texturizing agent',
#  'sodium dl-malate': 'humectant',
#  'sodium erythorbate (sodium isoascorbate)': 'antioxidant',
#  'sodium ethyl para-hydroxybenzoate': 'preservative',
#  'sodium ferrocyanide': 'anticaking agent',
#  'sodium formate': 'preservative',
#  'sodium fumarates': 'acidity regulator',
#  'sodium gluconate': 'thickener',
#  'sodium hydrogen carbonate': 'thickener',
#  'sodium hydrogen dl-malate': 'humectant',
#  'sodium hydrogen sulfate': 'acidity regulator',
#  'sodium hydrogen sulfite': 'preservative',
#  'sodium hydroxide': 'acidity regulator',
#  'sodium l(+)-tartrate': 'sequestrant',
#  'sodium l-aspartate': 'flavour enhancer',
#  'sodium lactate': 'bodying agent',
#  'sodium laurylsulfate': 'emulsifier',
#  'sodium metabisulfite': 'preservative',
#  'sodium metasilicate': 'anticaking agent',
#  'sodium methyl para-hydroxybenzoate': 'preservative',
#  'sodium nitrate': 'preservative',
#  'sodium nitrite': 'preservative',
#  'sodium oleyl lactylate': 'stabilizer',
#  'sodium ortho-phenylphenol': 'preservative',
#  'sodium phosphates': '',
#  'sodium polyacrylate': 'stabilizer',
#  'sodium polyphosphate': 'texturizing agent',
#  'sodium potassium hexametaphosphate': 'texturizing agent',
#  'sodium potassium triphosphate': 'stabilizer',
#  'sodium propionate': 'preservative',
#  'sodium propyl para-hydroxybenzoate': 'preservative',
#  'sodium saccharin': 'sweetener',
#  'sodium sesquicarbonate': 'raising agent',
#  'sodium silicate': 'anticaking agent',
#  'sodium sorbate': 'preservative',
#  'sodium stearoyl fumarate': 'emulsifier',
#  'sodium stearoyl lactylate': 'stabilizer',
#  'sodium sulfate': 'acidity regulator',
#  'sodium sulfite': 'preservative',
#  'sodium tartrates': '',
#  'sodium thiosulfate': 'sequestrant',
#  'sorbic acid': 'preservative',
#  'sorbitan monolaurate': 'stabilizer',
#  'sorbitan monooleate': 'stabilizer',
#  'sorbitan monopalmitate': 'emulsifier',
#  'sorbitan monostearate': 'stabilizer',
#  'sorbitan trioleate': 'stabilizer',
#  'sorbitan tristearate': 'stabilizer',
#  'sorbitol': 'texturizing agent',
#  'sorbitol syrup': 'texturizing agent',
#  'soybean hemicellulose': 'thickener',
#  'spermaceti wax': 'glazing agent',
#  'spirulina extract': 'colour',
#  'stannous chloride': 'colour retention agent',
#  'starch acetate': 'thickener',
#  'starch aluminium octenyl succinate': 'stabilizer',
#  'starch sodium octenyl succinate': 'thickener',
#  'starches, enzyme treated': 'thickener',
#  'stearyl citrate': 'sequestrant',
#  'stearyl tartrate': 'flour treatment agent',
#  'steviol glycosides from stevia rebaudiana bertoni (steviol glycosides from stevia)': 'sweetener',
#  'stigmasterol-rich plant sterols': 'stabilizer',
#  'succinic acid': 'acidity regulator',
#  'succinylated monoglycerides': 'stabilizer',
#  'succistearin': 'emulsifier',
#  'sucralose (trichlorogalactosucrose)': 'sweetener',
#  'sucroglycerides': 'emulsifier',
#  'sucrose acetate isobutyrate': 'stabilizer',
#  'sucrose esters of fatty acids': 'stabilizer',
#  'sucrose oligoesters, type i and type ii': 'stabilizer',
#  'sulfur dioxide': 'preservative',
#  'sulfuric acid': 'acidity regulator',
#  'sunset yellow fcf': 'colour',
#  'superglycerinated hydrogenated rapeseed oil': 'emulsifier',
#  'tagatose, d-': 'sweetener',
#  'tagetes extract': 'colour',
#  'talc': 'texturizing agent',
#  'tamarind seed polysaccharide': 'thickener',
#  'tannic acid (tannins)': 'thickener',
#  'tara gum': 'thickener',
#  'tartaric acid esters of mono- and diglycerides of fatty acids': 'stabilizer',
#  'tartaric acid, l(+)-': 'sequestrant',
#  'tartrazine': 'colour',
#  'tertiary butylhydroquinone': 'antioxidant',
#  'tetrapotassium diphosphate': 'texturizing agent',
#  'tetrasodium diphosphate': 'texturizing agent',
#  'thaumatin': 'sweetener',
#  'thermally oxidized soya bean oil interacted with mono- and diglycerides of fatty acids': 'emulsifier',
#  'thiabendazole': 'preservative',
#  'thiodipropionic acid': 'antioxidant',
#  'titanium dioxide': 'colour',
#  'tocopherol concentrate, mixed': 'antioxidant',
#  'tocopherol, d-alpha-': 'antioxidant',
#  'tocopherol, delta-, synthetic': 'antioxidant',
#  'tocopherol, dl-alpha-': 'antioxidant',
#  'tocopherol, gamma-, synthetic': 'antioxidant',
#  'tocopherols': '',
#  'tragacanth gum': 'thickener',
#  'triacetin': 'humectant',
#  'triammonium citrate': 'acidity regulator',
#  'tricalcium citrate': 'stabilizer',
#  'tricalcium phosphate': 'texturizing agent',
#  'triethyl citrate': 'sequestrant',
#  'trimagnesium phosphate': 'thickener',
#  'tripotassium citrate': 'stabilizer',
#  'tripotassium phosphate': 'texturizing agent',
#  'trisodium citrate': 'stabilizer',
#  'trisodium diphosphate': 'texturizing agent',
#  'trisodium phosphate': 'texturizing agent',
#  'turmeric': 'colour',
#  'urea (carbamide)': 'flour treatment agent',
#  'vegetable carbon': 'colour',
#  'violoxanthin': 'colour',
#  'wax esters': 'glazing agent',
#  'xanthan gum': 'thickener',
#  'xylitol': 'thickener',
#  'yeast mannoproteins': 'stabilizer',
#  'yellow 2g': 'colour',
#  'zeaxanthin, synthetic': 'colour',
#  'zeaxanthin-rich extract from tagetes erecta': 'colour',
#  'zinc acetate': 'flavour enhancer',
#  'zinc silicate': 'anticaking agent',
#  'î²-carotene- rich extract from dunaliella salina': 'colour'}

# %%
# export
with open("chemicals.json", "w") as outfile: 
    json.dump(d, outfile)
